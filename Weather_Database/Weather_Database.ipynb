# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests

# %%
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | balezino
# Processing Record 3 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | whitehorse
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | meadow lake
# Processing Record 9 of Set 1 | westport
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | ilam
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | ilulissat
# Processing Record 15 of Set 1 | sambava
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | maumere
# Processing Record 19 of Set 1 | jiayuguan
# Processing Record 20 of Set 1 | sokoni
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | nanortalik
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | axim
# Processing Record 28 of Set 1 | touros
# Processing Record 29 of Set 1 | mweka
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | palauig
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 1 | samarai
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | sola
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | flinders
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | moose factory
# Processing Record 44 of Set 1 | chapais
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | nadym
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | bontang
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | puerto escondido
# Processing Record 3 of Set 2 | kaduy
# Processing Record 4 of Set 2 | vao
# Processing Record 5 of Set 2 | vanimo
# Processing Record 6 of Set 2 | manokwari
# Processing Record 7 of Set 2 | leningradskiy
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | cayenne
# Processing Record 10 of Set 2 | hare bay
# Processing Record 11 of Set 2 | menomonie
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | along
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | jamame
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | dubai
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | turka
# Processing Record 21 of Set 2 | barentu
# Processing Record 22 of Set 2 | aklavik
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | medea
# Processing Record 25 of Set 2 | broken hill
# Processing Record 26 of Set 2 | kaspiyskiy
# Processing Record 27 of Set 2 | constitucion
# Processing Record 28 of Set 2 | north bend
# Processing Record 29 of Set 2 | qaqortoq
# Processing Record 30 of Set 2 | altenburg
# Processing Record 31 of Set 2 | teahupoo
# Processing Record 32 of Set 2 | kholodnyy
# Processing Record 33 of Set 2 | jinka
# Processing Record 34 of Set 2 | san ramon
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | kalabo
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | clyde river
# Processing Record 40 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 2 | sangar
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | hervey bay
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | yarmouth
# Processing Record 48 of Set 2 | svetlogorsk
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 3 | waipawa
# Processing Record 2 of Set 3 | apricena
# Processing Record 3 of Set 3 | kailua
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | jibuti
# Processing Record 6 of Set 3 | ahuimanu
# Processing Record 7 of Set 3 | wencheng
# Processing Record 8 of Set 3 | college
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | saint-augustin
# Processing Record 11 of Set 3 | turukhansk
# Processing Record 12 of Set 3 | san cristobal
# Processing Record 13 of Set 3 | kaeo
# Processing Record 14 of Set 3 | najran
# Processing Record 15 of Set 3 | saint-joseph
# Processing Record 16 of Set 3 | pangnirtung
# Processing Record 17 of Set 3 | ust-nera
# Processing Record 18 of Set 3 | san jose
# Processing Record 19 of Set 3 | tateyama
# Processing Record 20 of Set 3 | mangrol
# Processing Record 21 of Set 3 | bristol
# Processing Record 22 of Set 3 | okhotsk
# Processing Record 23 of Set 3 | quesnel
# Processing Record 24 of Set 3 | pacific grove
# Processing Record 25 of Set 3 | cairns
# Processing Record 26 of Set 3 | kodiak
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | brae
# Processing Record 30 of Set 3 | dingle
# Processing Record 31 of Set 3 | katsuura
# Processing Record 32 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 3 | bida
# Processing Record 34 of Set 3 | orocue
# Processing Record 35 of Set 3 | hampton
# Processing Record 36 of Set 3 | buin
# Processing Record 37 of Set 3 | laguna
# Processing Record 38 of Set 3 | salalah
# Processing Record 39 of Set 3 | tomatlan
# Processing Record 40 of Set 3 | vavuniya
# Processing Record 41 of Set 3 | jabinyanah
# Processing Record 42 of Set 3 | mandalgovi
# Processing Record 43 of Set 3 | nelson bay
# Processing Record 44 of Set 3 | kavaratti
# Processing Record 45 of Set 3 | sabzevar
# Processing Record 46 of Set 3 | new norfolk
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | necochea
# Processing Record 50 of Set 3 | oktyabrskoye
# Processing Record 1 of Set 4 | atambua
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | cam ranh
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | avera
# Processing Record 6 of Set 4 | rio grande
# Processing Record 7 of Set 4 | mizdah
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | mnogovershinnyy
# Processing Record 10 of Set 4 | west bay
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | mackay
# Processing Record 13 of Set 4 | lengshuijiang
# Processing Record 14 of Set 4 | khandyga
# Processing Record 15 of Set 4 | tabou
# Processing Record 16 of Set 4 | tiksi
# Processing Record 17 of Set 4 | caravelas
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | half moon bay
# Processing Record 22 of Set 4 | svetlyy
# Processing Record 23 of Set 4 | palmer
# Processing Record 24 of Set 4 | shushtar
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | goderich
# Processing Record 27 of Set 4 | eureka
# Processing Record 28 of Set 4 | mongoumba
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | puerto lopez
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | twin falls
# Processing Record 33 of Set 4 | gelemso
# Processing Record 34 of Set 4 | gat
# Processing Record 35 of Set 4 | llata
# Processing Record 36 of Set 4 | linqiong
# Processing Record 37 of Set 4 | kruisfontein
# Processing Record 38 of Set 4 | pau dos ferros
# Processing Record 39 of Set 4 | tazovskiy
# Processing Record 40 of Set 4 | port hedland
# Processing Record 41 of Set 4 | norman wells
# Processing Record 42 of Set 4 | granada
# Processing Record 43 of Set 4 | banjar
# Processing Record 44 of Set 4 | zhongshu
# Processing Record 45 of Set 4 | lubango
# Processing Record 46 of Set 4 | durusu
# Processing Record 47 of Set 4 | lashio
# Processing Record 48 of Set 4 | burnie
# Processing Record 49 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 4 | innisfail
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | upernavik
# Processing Record 3 of Set 5 | gornopravdinsk
# Processing Record 4 of Set 5 | saint anthony
# Processing Record 5 of Set 5 | ulu-telyak
# Processing Record 6 of Set 5 | lazaro cardenas
# Processing Record 7 of Set 5 | sarany
# Processing Record 8 of Set 5 | kutum
# Processing Record 9 of Set 5 | xuanhua
# Processing Record 10 of Set 5 | bogorodskoye
# Processing Record 11 of Set 5 | poum
# Processing Record 12 of Set 5 | ola
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | juba
# Processing Record 15 of Set 5 | ngunguru
# Processing Record 16 of Set 5 | ulaanbaatar
# Processing Record 17 of Set 5 | uribia
# Processing Record 18 of Set 5 | belmonte
# Processing Record 19 of Set 5 | arlit
# Processing Record 20 of Set 5 | cidreira
# Processing Record 21 of Set 5 | kolosovka
# Processing Record 22 of Set 5 | carnarvon
# Processing Record 23 of Set 5 | kerki
# City not found. Skipping...
# Processing Record 24 of Set 5 | esna
# Processing Record 25 of Set 5 | fortuna
# Processing Record 26 of Set 5 | maceio
# Processing Record 27 of Set 5 | sabratah
# Processing Record 28 of Set 5 | kanashevo
# Processing Record 29 of Set 5 | kurumkan
# Processing Record 30 of Set 5 | tuktoyaktuk
# Processing Record 31 of Set 5 | airai
# Processing Record 32 of Set 5 | pochutla
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 5 | bac lieu
# Processing Record 37 of Set 5 | klaksvik
# Processing Record 38 of Set 5 | ribeira grande
# Processing Record 39 of Set 5 | pevek
# Processing Record 40 of Set 5 | sechura
# Processing Record 41 of Set 5 | hamilton
# Processing Record 42 of Set 5 | la ronge
# Processing Record 43 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 44 of Set 5 | chimbarongo
# Processing Record 45 of Set 5 | toro
# Processing Record 46 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 5 | yumen
# Processing Record 48 of Set 5 | sawtell
# Processing Record 49 of Set 5 | sao jose do campestre
# Processing Record 50 of Set 5 | pokhara
# Processing Record 1 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 6 | nuuk
# Processing Record 3 of Set 6 | iqaluit
# Processing Record 4 of Set 6 | henties bay
# Processing Record 5 of Set 6 | banda aceh
# Processing Record 6 of Set 6 | tonj
# Processing Record 7 of Set 6 | nyurba
# Processing Record 8 of Set 6 | rawson
# Processing Record 9 of Set 6 | verkhnyaya inta
# Processing Record 10 of Set 6 | pirovskoye
# Processing Record 11 of Set 6 | warmbad
# Processing Record 12 of Set 6 | yulara
# Processing Record 13 of Set 6 | bethel
# Processing Record 14 of Set 6 | campo verde
# Processing Record 15 of Set 6 | quatre cocos
# Processing Record 16 of Set 6 | mount isa
# Processing Record 17 of Set 6 | talara
# Processing Record 18 of Set 6 | ambilobe
# Processing Record 19 of Set 6 | gualeguay
# Processing Record 20 of Set 6 | cabo san lucas
# Processing Record 21 of Set 6 | ambon
# Processing Record 22 of Set 6 | rivers
# Processing Record 23 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 24 of Set 6 | magadan
# Processing Record 25 of Set 6 | ayagoz
# Processing Record 26 of Set 6 | borama
# City not found. Skipping...
# Processing Record 27 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 6 | nemuro
# Processing Record 29 of Set 6 | codrington
# Processing Record 30 of Set 6 | qandala
# Processing Record 31 of Set 6 | kasongo-lunda
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | aripuana
# Processing Record 34 of Set 6 | ewa beach
# Processing Record 35 of Set 6 | luanda
# Processing Record 36 of Set 6 | nouadhibou
# Processing Record 37 of Set 6 | radford
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | puerto del rosario
# Processing Record 41 of Set 6 | camacha
# Processing Record 42 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 6 | lichinga
# Processing Record 44 of Set 6 | sept-iles
# Processing Record 45 of Set 6 | belaya gora
# Processing Record 46 of Set 6 | alice springs
# Processing Record 47 of Set 6 | orda
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | chulym
# Processing Record 50 of Set 6 | lebu
# Processing Record 1 of Set 7 | brigantine
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | amapa
# Processing Record 4 of Set 7 | padang
# Processing Record 5 of Set 7 | comodoro rivadavia
# Processing Record 6 of Set 7 | narsaq
# Processing Record 7 of Set 7 | chermoz
# Processing Record 8 of Set 7 | ixtapa
# Processing Record 9 of Set 7 | don sak
# Processing Record 10 of Set 7 | russellville
# Processing Record 11 of Set 7 | omsukchan
# Processing Record 12 of Set 7 | nioro
# Processing Record 13 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 7 | fianarantsoa
# Processing Record 15 of Set 7 | ligayan
# Processing Record 16 of Set 7 | bathurst
# Processing Record 17 of Set 7 | saint george
# Processing Record 18 of Set 7 | linjiang
# Processing Record 19 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | havre-saint-pierre
# Processing Record 21 of Set 7 | aksu
# Processing Record 22 of Set 7 | alofi
# Processing Record 23 of Set 7 | coahuayana
# Processing Record 24 of Set 7 | wasilla
# Processing Record 25 of Set 7 | ciudad bolivar
# Processing Record 26 of Set 7 | hasaki
# Processing Record 27 of Set 7 | uyuni
# Processing Record 28 of Set 7 | homer
# Processing Record 29 of Set 7 | ancud
# Processing Record 30 of Set 7 | benghazi
# Processing Record 31 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 32 of Set 7 | portland
# Processing Record 33 of Set 7 | ferme-neuve
# Processing Record 34 of Set 7 | izumo
# Processing Record 35 of Set 7 | querecotillo
# Processing Record 36 of Set 7 | knysna
# Processing Record 37 of Set 7 | kashi
# Processing Record 38 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 40 of Set 7 | hobyo
# Processing Record 41 of Set 7 | tall kayf
# Processing Record 42 of Set 7 | cumra
# Processing Record 43 of Set 7 | srednekolymsk
# Processing Record 44 of Set 7 | marsh harbour
# Processing Record 45 of Set 7 | acajutla
# Processing Record 46 of Set 7 | lagunas
# Processing Record 47 of Set 7 | fukue
# Processing Record 48 of Set 7 | saint-michel-des-saints
# Processing Record 49 of Set 7 | sungaipenuh
# Processing Record 50 of Set 7 | togur
# Processing Record 1 of Set 8 | taitung
# Processing Record 2 of Set 8 | goure
# Processing Record 3 of Set 8 | andenes
# Processing Record 4 of Set 8 | binzhou
# Processing Record 5 of Set 8 | gravdal
# Processing Record 6 of Set 8 | harnosand
# Processing Record 7 of Set 8 | borogontsy
# Processing Record 8 of Set 8 | hvolsvollur
# Processing Record 9 of Set 8 | dhidhdhoo
# Processing Record 10 of Set 8 | canutama
# Processing Record 11 of Set 8 | farafangana
# Processing Record 12 of Set 8 | nehe
# Processing Record 13 of Set 8 | oussouye
# Processing Record 14 of Set 8 | colorado
# Processing Record 15 of Set 8 | broome
# Processing Record 16 of Set 8 | hofn
# Processing Record 17 of Set 8 | manono
# Processing Record 18 of Set 8 | sur
# Processing Record 19 of Set 8 | roald
# Processing Record 20 of Set 8 | freetown
# Processing Record 21 of Set 8 | suclayin
# Processing Record 22 of Set 8 | krasnoborsk
# Processing Record 23 of Set 8 | mareeba
# Processing Record 24 of Set 8 | sioux lookout
# Processing Record 25 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 8 | rocha
# Processing Record 27 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 8 | pozo colorado
# Processing Record 29 of Set 8 | kachiry
# Processing Record 30 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 31 of Set 8 | coquimbo
# Processing Record 32 of Set 8 | naranjal
# Processing Record 33 of Set 8 | bud
# Processing Record 34 of Set 8 | boissevain
# Processing Record 35 of Set 8 | sorland
# Processing Record 36 of Set 8 | christchurch
# Processing Record 37 of Set 8 | falmouth
# Processing Record 38 of Set 8 | lumberton
# Processing Record 39 of Set 8 | mtambile
# Processing Record 40 of Set 8 | katherine
# Processing Record 41 of Set 8 | saraland
# Processing Record 42 of Set 8 | chernyshevskiy
# Processing Record 43 of Set 8 | plouzane
# Processing Record 44 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 8 | shingu
# Processing Record 46 of Set 8 | pokrovskoye
# Processing Record 47 of Set 8 | vagur
# Processing Record 48 of Set 8 | yichun
# Processing Record 49 of Set 8 | atar
# Processing Record 50 of Set 8 | bambous virieux
# Processing Record 1 of Set 9 | ostrovnoy
# Processing Record 2 of Set 9 | thompson
# Processing Record 3 of Set 9 | kamenskiy
# Processing Record 4 of Set 9 | vestmannaeyjar
# Processing Record 5 of Set 9 | andselv
# City not found. Skipping...
# Processing Record 6 of Set 9 | vila franca do campo
# Processing Record 7 of Set 9 | grindavik
# Processing Record 8 of Set 9 | luderitz
# Processing Record 9 of Set 9 | santa cruz
# Processing Record 10 of Set 9 | tumen
# Processing Record 11 of Set 9 | hualmay
# Processing Record 12 of Set 9 | zhangjiakou
# Processing Record 13 of Set 9 | itoman
# Processing Record 14 of Set 9 | richards bay
# Processing Record 15 of Set 9 | pizarro
# Processing Record 16 of Set 9 | kharsawan
# Processing Record 17 of Set 9 | talcahuano
# Processing Record 18 of Set 9 | lasa
# Processing Record 19 of Set 9 | dasoguz
# Processing Record 20 of Set 9 | hay river
# Processing Record 21 of Set 9 | deputatskiy
# Processing Record 22 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 9 | payo
# Processing Record 24 of Set 9 | hami
# Processing Record 25 of Set 9 | havelock
# Processing Record 26 of Set 9 | vigrestad
# Processing Record 27 of Set 9 | chumikan
# Processing Record 28 of Set 9 | mayumba
# Processing Record 29 of Set 9 | les cayes
# Processing Record 30 of Set 9 | olavarria
# Processing Record 31 of Set 9 | ahipara
# Processing Record 32 of Set 9 | morro bay
# Processing Record 33 of Set 9 | nova olinda do norte
# Processing Record 34 of Set 9 | morant bay
# Processing Record 35 of Set 9 | boromo
# Processing Record 36 of Set 9 | lompoc
# Processing Record 37 of Set 9 | chicama
# Processing Record 38 of Set 9 | bairiki
# Processing Record 39 of Set 9 | meulaboh
# Processing Record 40 of Set 9 | san roque
# Processing Record 41 of Set 9 | port augusta
# Processing Record 42 of Set 9 | bahia blanca
# Processing Record 43 of Set 9 | sansai
# City not found. Skipping...
# Processing Record 44 of Set 9 | igarka
# Processing Record 45 of Set 9 | taltal
# Processing Record 46 of Set 9 | port victoria
# Processing Record 47 of Set 9 | kendari
# Processing Record 48 of Set 9 | tezu
# Processing Record 49 of Set 9 | haines junction
# Processing Record 50 of Set 9 | mabaruma
# Processing Record 1 of Set 10 | uni
# Processing Record 2 of Set 10 | forestville
# Processing Record 3 of Set 10 | cap malheureux
# Processing Record 4 of Set 10 | saldanha
# Processing Record 5 of Set 10 | linhai
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | eyl
# Processing Record 8 of Set 10 | montijo
# Processing Record 9 of Set 10 | guanare
# Processing Record 10 of Set 10 | boende
# Processing Record 11 of Set 10 | gampaha
# Processing Record 12 of Set 10 | leshukonskoye
# Processing Record 13 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 10 | tanabi
# Processing Record 15 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 16 of Set 10 | callaguip
# Processing Record 17 of Set 10 | sorong
# Processing Record 18 of Set 10 | cacoal
# Processing Record 19 of Set 10 | suntar
# Processing Record 20 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 10 | prince rupert
# Processing Record 22 of Set 10 | bolshoy lug
# Processing Record 23 of Set 10 | batemans bay
# Processing Record 24 of Set 10 | boa vista
# Processing Record 25 of Set 10 | maragogi
# Processing Record 26 of Set 10 | ratnagiri
# Processing Record 27 of Set 10 | farmington
# Processing Record 28 of Set 10 | bathsheba
# Processing Record 29 of Set 10 | svebolle
# Processing Record 30 of Set 10 | lagoa
# Processing Record 31 of Set 10 | karratha
# Processing Record 32 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 10 | nosy varika
# Processing Record 34 of Set 10 | kemalpasa
# Processing Record 35 of Set 10 | hitachi
# Processing Record 36 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 37 of Set 10 | surgana
# Processing Record 38 of Set 10 | akita
# Processing Record 39 of Set 10 | san quintin
# Processing Record 40 of Set 10 | sayyan
# Processing Record 41 of Set 10 | treinta y tres
# Processing Record 42 of Set 10 | bulgan
# Processing Record 43 of Set 10 | san andres
# Processing Record 44 of Set 10 | qeshm
# Processing Record 45 of Set 10 | stephenville
# Processing Record 46 of Set 10 | senanga
# Processing Record 47 of Set 10 | dharchula
# Processing Record 48 of Set 10 | ugoofaaru
# Processing Record 49 of Set 10 | alyangula
# Processing Record 50 of Set 10 | mao
# Processing Record 1 of Set 11 | raudeberg
# Processing Record 2 of Set 11 | mahanoro
# Processing Record 3 of Set 11 | tuy hoa
# Processing Record 4 of Set 11 | chiang khong
# Processing Record 5 of Set 11 | sao miguel do araguaia
# Processing Record 6 of Set 11 | russell
# Processing Record 7 of Set 11 | urumqi
# Processing Record 8 of Set 11 | baghdad
# Processing Record 9 of Set 11 | kholmogory
# Processing Record 10 of Set 11 | tual
# Processing Record 11 of Set 11 | koani
# Processing Record 12 of Set 11 | port elizabeth
# Processing Record 13 of Set 11 | lodja
# Processing Record 14 of Set 11 | mayo
# Processing Record 15 of Set 11 | tura
# Processing Record 16 of Set 11 | champlin
# Processing Record 17 of Set 11 | zhigansk
# Processing Record 18 of Set 11 | nome
# Processing Record 19 of Set 11 | mwene-ditu
# Processing Record 20 of Set 11 | namibe
# Processing Record 21 of Set 11 | la tuque
# Processing Record 22 of Set 11 | sao felix do xingu
# Processing Record 23 of Set 11 | punta alta
# Processing Record 24 of Set 11 | xiongshi
# City not found. Skipping...
# Processing Record 25 of Set 11 | batangafo
# Processing Record 26 of Set 11 | dobroye
# Processing Record 27 of Set 11 | tadine
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | olean
# Processing Record 30 of Set 11 | kieta
# Processing Record 31 of Set 11 | maxixe
# Processing Record 32 of Set 11 | pitimbu
# Processing Record 33 of Set 11 | imaculada
# Processing Record 34 of Set 11 | madang
# Processing Record 35 of Set 11 | toamasina
# Processing Record 36 of Set 11 | hovd
# Processing Record 37 of Set 11 | geraldton
# Processing Record 38 of Set 11 | thunder bay
# Processing Record 39 of Set 11 | lata
# Processing Record 40 of Set 11 | walvis bay
# Processing Record 41 of Set 11 | mugur-aksy
# Processing Record 42 of Set 11 | mahbubnagar
# Processing Record 43 of Set 11 | whitecourt
# Processing Record 44 of Set 11 | linguere
# Processing Record 45 of Set 11 | alamogordo
# Processing Record 46 of Set 11 | pitsunda
# Processing Record 47 of Set 11 | iki-burul
# Processing Record 48 of Set 11 | burica
# City not found. Skipping...
# Processing Record 49 of Set 11 | kundiawa
# Processing Record 50 of Set 11 | te anau
# Processing Record 1 of Set 12 | isangel
# Processing Record 2 of Set 12 | guane
# Processing Record 3 of Set 12 | bonavista
# Processing Record 4 of Set 12 | port keats
# Processing Record 5 of Set 12 | kuching
# Processing Record 6 of Set 12 | bani
# Processing Record 7 of Set 12 | rabat
# Processing Record 8 of Set 12 | zheshart
# Processing Record 9 of Set 12 | cherkasskoye
# Processing Record 10 of Set 12 | soissons
# Processing Record 11 of Set 12 | aswan
# Processing Record 12 of Set 12 | marienburg
# Processing Record 13 of Set 12 | port macquarie
# Processing Record 14 of Set 12 | kushima
# Processing Record 15 of Set 12 | charters towers
# Processing Record 16 of Set 12 | husavik
# Processing Record 17 of Set 12 | borovoy
# Processing Record 18 of Set 12 | siuna
# Processing Record 19 of Set 12 | cabedelo
# Processing Record 20 of Set 12 | the valley
# Processing Record 21 of Set 12 | kibala
# Processing Record 22 of Set 12 | san gabriel casa blanca
# Processing Record 23 of Set 12 | hokitika
# Processing Record 24 of Set 12 | tecoanapa
# Processing Record 25 of Set 12 | villa union
# Processing Record 26 of Set 12 | saluzzo
# Processing Record 27 of Set 12 | charyshskoye
# Processing Record 28 of Set 12 | mardin
# Processing Record 29 of Set 12 | bousso
# Processing Record 30 of Set 12 | guerrero negro
# Processing Record 31 of Set 12 | lima
# Processing Record 32 of Set 12 | niksic
# Processing Record 33 of Set 12 | mogadishu
# Processing Record 34 of Set 12 | komatsu
# Processing Record 35 of Set 12 | pisco
# Processing Record 36 of Set 12 | riyadh
# Processing Record 37 of Set 12 | cabra
# Processing Record 38 of Set 12 | oktyabrskiy
# Processing Record 39 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 12 | vostok
# Processing Record 41 of Set 12 | grants pass
# Processing Record 42 of Set 12 | pemba
# Processing Record 43 of Set 12 | zhoucheng
# Processing Record 44 of Set 12 | muros
# Processing Record 45 of Set 12 | fengcheng
# Processing Record 46 of Set 12 | sturgeon bay
# Processing Record 47 of Set 12 | ponta delgada
# Processing Record 48 of Set 12 | miri
# Processing Record 49 of Set 12 | arcata
# Processing Record 50 of Set 12 | fare
# Processing Record 1 of Set 13 | lokosovo
# Processing Record 2 of Set 13 | kayerkan
# Processing Record 3 of Set 13 | katangli
# Processing Record 4 of Set 13 | nara
# Processing Record 5 of Set 13 | jiwani
# Processing Record 6 of Set 13 | liuzhou
# Processing Record 7 of Set 13 | freeport
# Processing Record 8 of Set 13 | olinda
# Processing Record 9 of Set 13 | kommunar
# Processing Record 10 of Set 13 | korla
# Processing Record 11 of Set 13 | cocorit
# Processing Record 12 of Set 13 | port lincoln
# Processing Record 13 of Set 13 | roswell
# Processing Record 14 of Set 13 | turayf
# Processing Record 15 of Set 13 | biak
# Processing Record 16 of Set 13 | okandja
# City not found. Skipping...
# Processing Record 17 of Set 13 | lewisporte
# Processing Record 18 of Set 13 | taikang
# Processing Record 19 of Set 13 | falakata
# Processing Record 20 of Set 13 | phnum penh
# City not found. Skipping...
# Processing Record 21 of Set 13 | tiznit
# Processing Record 22 of Set 13 | bandarbeyla
# Processing Record 23 of Set 13 | mayfield heights
# Processing Record 24 of Set 13 | takoradi
# Processing Record 25 of Set 13 | batticaloa
# Processing Record 26 of Set 13 | yelatma
# Processing Record 27 of Set 13 | presidencia roque saenz pena
# Processing Record 28 of Set 13 | kahului
# Processing Record 29 of Set 13 | akyab
# Processing Record 30 of Set 13 | swiecie
# Processing Record 31 of Set 13 | yatou
# Processing Record 32 of Set 13 | manavalakurichi
# Processing Record 33 of Set 13 | rizhao
# Processing Record 34 of Set 13 | gambela
# Processing Record 35 of Set 13 | tsevie
# Processing Record 36 of Set 13 | leh
# Processing Record 37 of Set 13 | xinglongshan
# Processing Record 38 of Set 13 | gizo
# Processing Record 39 of Set 13 | guatire
# Processing Record 40 of Set 13 | carauari
# Processing Record 41 of Set 13 | zanjan
# Processing Record 42 of Set 13 | malindi
# Processing Record 43 of Set 13 | loandjili
# Processing Record 44 of Set 13 | businga
# Processing Record 45 of Set 13 | nakamura
# Processing Record 46 of Set 13 | miastko
# Processing Record 47 of Set 13 | manjacaze
# Processing Record 48 of Set 13 | wanaka
# Processing Record 49 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 13 | kamina
# Processing Record 1 of Set 14 | champerico
# Processing Record 2 of Set 14 | emerald
# Processing Record 3 of Set 14 | san carlos de bariloche
# Processing Record 4 of Set 14 | baykit
# Processing Record 5 of Set 14 | newport
# Processing Record 6 of Set 14 | byron bay
# Processing Record 7 of Set 14 | buluang
# Processing Record 8 of Set 14 | wajima
# Processing Record 9 of Set 14 | sao joao da barra
# Processing Record 10 of Set 14 | priiskovyy
# Processing Record 11 of Set 14 | sandusky
# Processing Record 12 of Set 14 | gunjur
# Processing Record 13 of Set 14 | komsomolskiy
# Processing Record 14 of Set 14 | santa rosa
# Processing Record 15 of Set 14 | dir
# Processing Record 16 of Set 14 | aykhal
# Processing Record 17 of Set 14 | los llanos de aridane
# Processing Record 18 of Set 14 | carora
# Processing Record 19 of Set 14 | kazachinskoye
# Processing Record 20 of Set 14 | asau
# Processing Record 21 of Set 14 | nanyamba
# Processing Record 22 of Set 14 | naustdal
# Processing Record 23 of Set 14 | lesnoy
# Processing Record 24 of Set 14 | williston
# Processing Record 25 of Set 14 | krivopolyanye
# City not found. Skipping...
# Processing Record 26 of Set 14 | barpeta
# Processing Record 27 of Set 14 | kocser
# Processing Record 28 of Set 14 | arroyos y esteros
# Processing Record 29 of Set 14 | brockville
# Processing Record 30 of Set 14 | canico
# Processing Record 31 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 14 | port said
# Processing Record 33 of Set 14 | kloulklubed
# Processing Record 34 of Set 14 | beira
# Processing Record 35 of Set 14 | vladeni
# Processing Record 36 of Set 14 | coihaique
# Processing Record 37 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 14 | vestmanna
# Processing Record 39 of Set 14 | taoudenni
# Processing Record 40 of Set 14 | diamantino
# Processing Record 41 of Set 14 | namatanai
# Processing Record 42 of Set 14 | buraydah
# Processing Record 43 of Set 14 | changji
# Processing Record 44 of Set 14 | nouakchott
# Processing Record 45 of Set 14 | kathmandu
# Processing Record 46 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 14 | ketchikan
# Processing Record 48 of Set 14 | natchez
# Processing Record 49 of Set 14 | krasnoselkup
# Processing Record 50 of Set 14 | matamoros
# Processing Record 1 of Set 15 | prizren
# Processing Record 2 of Set 15 | candido mendes
# Processing Record 3 of Set 15 | havoysund
# Processing Record 4 of Set 15 | nampula
# Processing Record 5 of Set 15 | naron
# Processing Record 6 of Set 15 | gazimurskiy zavod
# Processing Record 7 of Set 15 | rodez
# Processing Record 8 of Set 15 | paso de carrasco
# Processing Record 9 of Set 15 | grootfontein
# Processing Record 10 of Set 15 | san ignacio
# Processing Record 11 of Set 15 | bursa
# Processing Record 12 of Set 15 | ilo
# Processing Record 13 of Set 15 | olga
# Processing Record 14 of Set 15 | iskateley
# Processing Record 15 of Set 15 | blora
# Processing Record 16 of Set 15 | nabire
# Processing Record 17 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 15 | gorontalo
# Processing Record 19 of Set 15 | yamaga
# Processing Record 20 of Set 15 | bilibino
# Processing Record 21 of Set 15 | aldan
# Processing Record 22 of Set 15 | black diamond
# Processing Record 23 of Set 15 | soyo
# Processing Record 24 of Set 15 | zheleznodorozhnyy
# Processing Record 25 of Set 15 | coolum beach
# Processing Record 26 of Set 15 | grand gaube
# Processing Record 27 of Set 15 | morondava
# Processing Record 28 of Set 15 | craig
# Processing Record 29 of Set 15 | lazurne
# Processing Record 30 of Set 15 | mindelo
# Processing Record 31 of Set 15 | manaure
# Processing Record 32 of Set 15 | syedove
# Processing Record 33 of Set 15 | mezhdurechensk
# Processing Record 34 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 15 | astorga
# Processing Record 36 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 37 of Set 15 | kampot
# Processing Record 38 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 15 | santa rosalia
# Processing Record 40 of Set 15 | kon tum
# Processing Record 41 of Set 15 | troitsk
# Processing Record 42 of Set 15 | basco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Sao Filipe  14.8961  -24.4956     73.22        69           0       12.24
# 1    Balezino  57.9796   53.0106     18.07       100          85        5.30
# 2     Mataura -46.1927  168.8643     62.44        50          89        1.48
# 3  Whitehorse  60.7161 -135.0538     31.10        65          75       11.50
# 4      Albany  42.6001  -73.9662     37.81        61          96        6.06
#
#   Country Current Description
# 0      CV           clear sky
# 1      RU     overcast clouds
# 2      NZ     overcast clouds
# 3      CA         shower rain
# 4      US     overcast clouds

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
new_cols = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_cols]
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sao Filipe      CV  14.8961  -24.4956     73.22        69           0
# 1    Balezino      RU  57.9796   53.0106     18.07       100          85
# 2     Mataura      NZ -46.1927  168.8643     62.44        50          89
# 3  Whitehorse      CA  60.7161 -135.0538     31.10        65          75
# 4      Albany      US  42.6001  -73.9662     37.81        61          96
#
#    Wind Speed Current Description
# 0       12.24           clear sky
# 1        5.30     overcast clouds
# 2        1.48     overcast clouds
# 3       11.50         shower rain
# 4        6.06     overcast clouds

# %%
city_data_df.tail()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 683         Kampot      KH  10.6167  104.1833     75.25        75          86
# 684  Santa Rosalia      MX  27.3167 -112.2833     70.65        27          88
# 685        Kon Tum      VN  14.3500  108.0000     60.94        95          71
# 686        Troitsk      RU  54.0979   61.5773     13.51        93          60
# 687          Basco      PH  20.4487  121.9702     75.25        76          96
#
#      Wind Speed Current Description
# 683        3.06     overcast clouds
# 684        2.84     overcast clouds
# 685        2.82       broken clouds
# 686        8.14       broken clouds
# 687       16.22     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
